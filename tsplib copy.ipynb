# %%
import os
import pickle
import tsplib95
import csv
import time
import pandas as pd
import numpy as np
import networkx as nx
from networkx.algorithms.approximation.traveling_salesman import *

# %%
def get_tsp_graph(name) -> nx.Graph:
    # load from pkl file if exists
    graph_file_path = os.path.join("tsp_dataset", f"{name}.graph.pkl")
    if os.path.exists(graph_file_path):
        # print(f"Loading {name} from pkl {graph_file_path}")
        with open(graph_file_path, "rb") as file:
            G = pickle.load(file)
        return G.to_undirected()

    tsp_file_path = os.path.join("tsp_dataset", f"{name}.tsp")
    # print(f"Loading {name} from tsplib {tsp_file_path}")
    problem = tsplib95.load(tsp_file_path)
    G = problem.get_graph()

    # remove redundant edges
    if problem.edge_weight_type == "EXPLICIT" and problem.edge_weight_format == "FULL_MATRIX":
        for u in G.nodes:
            for v in G.nodes:
                if u > v:
                    G.remove_edge(u, v)

    # remove self loops
    loop_edges = list(nx.selfloop_edges(G))
    G.remove_edges_from(loop_edges)

    # save as pkl file
    with open(graph_file_path, "wb") as file:
        print(f"Saving {name} to pkl {graph_file_path}")
        pickle.dump(G, file)

    return G

# %%
tsp_dataset_file_path = os.path.join("tsp_dataset", "tsp_dataset.csv")
print(f"Loading tsp dataset from {tsp_dataset_file_path}")
tsp_dataset = pd.read_csv(tsp_dataset_file_path)
# Out:
# Loading tsp dataset from tsp_dataset\tsp_dataset.csv

# %%
def get_opt_tour_length(name):
    return tsp_dataset[tsp_dataset["name"] == name]["opt_tour_length"].values[0]

# %%
def get_tour_length(G: nx.graph, tour: list):
    tour_length = 0
    for i in range(len(tour) - 1):
        u, v = tour[i], tour[i + 1]
        w = G[u][v]["weight"]
        tour_length += w
    return tour_length

# %%
def get_apx_ratio(G: nx.graph, tour: list):
    return get_tour_length(G, tour) / get_opt_tour_length(G.name)

# %%
tsp_dataset
# Out:
#          name  dimension  opt_tour_length type  \
# 0     burma14         14             3323  TSP
# 1   ulysses16         16             6859  TSP
# 2        gr17         17             2085  TSP
# 3        gr21         21             2707  TSP
# 4   ulysses22         22             7013  TSP
# ..        ...        ...              ...  ...
# 91      u2319       2319           234256  TSP
# 92     pr2392       2392           378032  TSP
# 93    pcb3038       3038           137694  TSP
# 94    fnl4461       4461           182566  TSP
# 95    pla7397       7397         23260728  TSP
#
#                                               comment edge_weight_type  \
# 0                       14-Staedte in Burma (Zaw Win)              GEO
# 1             Odyssey of Ulysses (Groetschel/Padberg)              GEO
# 2                        17-city problem (Groetschel)         EXPLICIT
# 3                        21-city problem (Groetschel)         EXPLICIT
# 4             Odyssey of Ulysses (Groetschel/Padberg)              GEO
# ..                                                ...              ...
# 91                         Drilling problem (Reinelt)           EUC_2D
# 92                2392-city problem (Padberg/Rinaldi)           EUC_2D
# 93                  Drilling problem (Junger/Reinelt)           EUC_2D
# 94  Die 5 neuen Laender Deutschlands (Ex-DDR) (Bac...           EUC_2D
# 95                   Programmed logic array (Johnson)          CEIL_2D
#
#    edge_weight_format
# 0            FUNCTION
# 1                 NaN
# 2      LOWER_DIAG_ROW
# 3      LOWER_DIAG_ROW
# 4                 NaN
# ..                ...
# 91                NaN
# 92                NaN
# 93                NaN
# 94                NaN
# 95                NaN
#
# [96 rows x 7 columns]

# %%
from mst import MST
st = MST()

# %%
def get_total_edge_weight(G: nx.graph):
    total_edge_weight = 0
    for u, v in G.edges:
        total_edge_weight += G[u][v]["weight"]
    return total_edge_weight

# %%
data = []

# %%
from simulated_annealing import SimulateAnnealing

# %%
with open("christofides_results.csv", "a", newline="") as csvfile:
    # writer = csv.writer(csvfile)

    for name in tsp_dataset["name"][:1]:
        print(name)

        G = get_tsp_graph(name)
        dimension = G.number_of_nodes()
        opt_tour_length = get_opt_tour_length(name)

        d = {
            "name": name,
            "dimension": dimension,
            "opt_tour_length": opt_tour_length,
        }

        start_time = time.time()

        tree = st.get_mst_k(G, 1)
        tour = christofides(G, tree=tree)
        
        end_time = time.time()
        elapsed_time = end_time - start_time
        
        tour_length = get_tour_length(G, tour)
        apx_ratio = tour_length / opt_tour_length

        d["tour_length"] = tour_length
        d["apx_ratio"] = apx_ratio
        d["elapsed_time"] = elapsed_time

        print(list(d.values()))
        # writer.writerow(d.values())
        
        # sa = SimulateAnnealing(
        #     graph=G,
        #     initial_solution=tour,
        #     max_iterations=100,
        #     initial_temperature=1000,
        #     cooling_rate=0.01,
        # )
        # sa_tour, sa_tour_length = sa.run()
        # print(sa_tour_length, sa_tour)
        
        simulated_annealing_tsp(
            G,
            init_cycle=tour,
            
        )
# Out:
# burma14
# ['burma14', 14, 3323, 3559, 1.0710201625037616, 0.013955831527709961]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 42
#      33 # writer.writerow(d.values())
#      35 sa = SimulateAnnealing(
#      36     graph=G,
#      37     initial_solution=tour,
#    (...)
#      40     cooling_rate=0.01,
#      41 )
# ---> 42 sa_tour, sa_tour_length = sa.run()
#      43 print(sa_tour_length, sa_tour)
#
# File c:\Users\utchchhwas\Desktop\Algo Project\copy\TSP\simulated_annealing.py:97, in SimulateAnnealing.run(self)
#      94 candidate_solution = self.generate_new_solution()
#      96 # evaluate new solution
# ---> 97 self.acceptance_test(candidate_solution)
#      99 # update trace
#     100 self.trace.append((self.current_solution, self.cost(self.current_solution)))
#
# File c:\Users\utchchhwas\Desktop\Algo Project\copy\TSP\simulated_annealing.py:73, in SimulateAnnealing.acceptance_test(self, candidate_solution)
#      69 def acceptance_test(self, candidate_solution: list):
#      70     '''
#      71     Acceptance test for the new solution
#      72     '''
# ---> 73     candidate_cost = self.cost(candidate_solution)
#      74     current_cost = self.cost(self.current_solution)
#      75     if candidate_cost < current_cost:
#
# File c:\Users\utchchhwas\Desktop\Algo Project\copy\TSP\simulated_annealing.py:52, in SimulateAnnealing.cost(self, solution)
#      48 def cost(self, solution: list):
#      49     '''
#      50     Calculate the cost of the solution
#      51     '''
# ---> 52     cost = sum(self.graph.get_edge_data(u, v)['weight'] for u, v in pairwise(solution))
#      54     return cost
#
# File c:\Users\utchchhwas\Desktop\Algo Project\copy\TSP\simulated_annealing.py:52, in <genexpr>(.0)
#      48 def cost(self, solution: list):
#      49     '''
#      50     Calculate the cost of the solution
#      51     '''
# ---> 52     cost = sum(self.graph.get_edge_data(u, v)['weight'] for u, v in pairwise(solution))
#      54     return cost
#
# TypeError: 'NoneType' object is not subscriptable
